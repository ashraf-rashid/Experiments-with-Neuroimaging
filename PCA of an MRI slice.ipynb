# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
image = nib.load("G:\\Fresh Alzheimer Raw images\\AD raw\\51_ADNI_002_S_0619_MR_MP-RAGE__br_raw_20060601215738863_1_S15147_I16392.nii")

# %%
imageData = image.get_fdata()

# %%
imageSlice = imageData[:,:,120]

# %%
plt.imshow((imageSlice[:,:,0]).T,cmap="gray",origin="lower")

# %%
import numpy as np

# %%
covarianceMatrix = np.cov(imageSlice[:,:,0],rowvar = False)

# %%
covarianceMatrix.shape
# Out:
# (256, 256)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=covarianceMatrix)

# %%
df.to_csv("G:\\Images for PCA analysis\\Test PCA analysis result\\covariance_matrix_result.csv")

# %% [markdown]
# Covariance analysis of masked images starts below

# %%
image = nib.load("G:\\Images for PCA analysis\\mask_smwc11_ADNI_005_S_0610_MR_MP-RAGE__br_raw_20060621110339771_1_S15727_I17303.nii")

# %%
imageData = image.get_fdata()

# %%
imageSlice = imageData[:,:,50]

# %%
plt.imshow(imageSlice.T,cmap="gray",origin="lower")

# %%
covarianceMatrix = np.cov(imageSlice,rowvar = False)
covarianceMatrix.shape
# Out:
# (145, 145)

# %%
df = pd.DataFrame(data=covarianceMatrix)

# %%
tempList = []

# %%
for i in range(0,121):
    for j in range(0,145):
        tempList.append(imageSlice[i][j])

# %%
tempArray = np.zeros([1,17545])
for i in range(0,17545):
    tempArray[0][i] = tempList[i]

# %%
tempArray.shape
# Out:
# (1, 17545)

# %%
# Out:
# array(0.0028001)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.99)

# %%
pca.fit(pixelArray)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.99, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
transformedData = pca.transform(imageArray)

# %%
transformedData.shape
# Out:
# (166, 57)

# %%
plt.imshow(transformedData,cmap="gray")
